# %% [markdown]
# <a href="https://www.kaggle.com/code/sonawanelalitsunil/bau-insectv2-ai-for-pest-detection-dl-100?scriptVersionId=225626953" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_9.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_18.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_33.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_54.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_35.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_29.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_15.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_30.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_3.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_52.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_20.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_20 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_51.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_17.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_53.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_16.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_58.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_27.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_46.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_12.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_48.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_43.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_8.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_40.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_5.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_45.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_38.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_13.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_50.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_36 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_36.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_47.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_1.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_34.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_19.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_55.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_0.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_21.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_23.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_0 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_25.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_4.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_1 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_24.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_41.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_59.jpg
# /kaggle/input/insectv2-dataset/pest/test/beetle/jpg_6.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_9.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_18.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_33.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_19 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_35.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_22 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_3.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_52.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_20.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_20 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_45 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_17.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_42 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_53.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_16.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_56.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_57.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_31.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_2.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_3 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_5.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_35 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_28.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_21 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_5 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_13.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_18 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_36 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_36.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_47.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_19.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_55.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_21.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_7.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_52 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_23.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_14.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_2 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_59.jpg
# /kaggle/input/insectv2-dataset/pest/test/mites/jpg_17 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_26.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_9.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_18.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_33.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_54.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_35.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_29.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_15.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_30.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_3.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_20.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_49.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_16.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_27.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_46.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_56.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_43.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_8.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_31.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_40.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_28.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_45.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_38.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_42.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_11.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_13.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_50.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_36.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_47.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_37.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_1.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_19.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_55.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_21.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_23.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_14.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_25.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_4.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_60.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_24.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_41.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_59.jpg
# /kaggle/input/insectv2-dataset/pest/test/grasshopper/jpg_6.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_26.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_9.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_18.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_44.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_33.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_29.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_15.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_3.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_51.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_17.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_53.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_58.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_27.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_12.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_48.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_57.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_43.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_2.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_40.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_5.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_38.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_11.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_1.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_19.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_0.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_21.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_6 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_23.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_14.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_4.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_24.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_41.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_32.jpg
# /kaggle/input/insectv2-dataset/pest/test/sawfly/jpg_6.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_26.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_44.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_33.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_54.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_35.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_3.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_52.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_20.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_49.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_53.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_12.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_56.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_43.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_8.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_31.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_2.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_40.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_5.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_28.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_45.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_11.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_5 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_13.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_50.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_36.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_37.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_1.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_34.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_44 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_0.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_14.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_4.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_2 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_41.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_59.jpg
# /kaggle/input/insectv2-dataset/pest/test/stem_borer/jpg_6.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_26.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_9.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_18.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_44.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_54.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_29.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_15.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_30.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_3.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_52.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_20.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_51.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_53.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_16.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_58.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_27.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_46.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_12.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_56.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_48.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_43.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_8.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_31.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_40.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_5.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_28.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_45.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_38.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_42.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_11.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_50.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_47.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_1.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_34.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_19.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_55.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_0.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_7.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_23.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_14.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_25.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_4.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_24.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_41.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_32.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_59.jpg
# /kaggle/input/insectv2-dataset/pest/test/mosquito/jpg_6.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_26.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_44.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_54.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_35.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_4 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_15.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_3.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_52.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_20.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_51.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_49.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_53.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_27.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_46.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_12.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_56.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_48.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_43.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_8.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_2.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_40.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_3 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_45.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_10 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_37.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_32 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_34.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_19.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_55.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_0.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_21.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_6 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_7.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_23.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_4.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_7 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_2 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_41.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_32.jpg
# /kaggle/input/insectv2-dataset/pest/test/armyworm/jpg_6.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_9.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_44.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_33.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_54.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_55 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_35.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_4 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_29.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_15.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_30.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_13 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_52.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_15 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_51.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_27.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_46.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_56.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_2.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_40.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_5.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_46 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_54 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_45.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_42.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_5 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_13.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_9 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_50.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_36.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_47.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_37.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_19.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_55.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_0.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_6 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_7.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_23.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_0 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_4.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_7 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_2 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_24.jpg
# /kaggle/input/insectv2-dataset/pest/test/aphids/jpg_6.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_26.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_9.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_44.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_33.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_35.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_29.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_15.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_52.jpg
# /kaggle/input/insectv2-dataset/pest/test/bollworm/jpg_20.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_19 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_16 - Copy (3).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_80 - Copy (4).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_22.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_55 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_10.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_39.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_4 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_26 - Copy (5).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_29.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_10 - Copy (4).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_36 - Copy (4).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_45 - Copy (3).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_91 - Copy (2).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_22 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_37 - Copy (4).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_70 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_92 - Copy - Copy (2).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_92 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_43 - Copy (4).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_81 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_71 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_71 - Copy (4) - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_61 - Copy (2).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_70.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_62 - Copy (3).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_43 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_10 - Copy (3).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_87 - Copy (3) - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_31 - Copy (2).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_61 - Copy (4).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_33 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_22 - Copy (2) - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_56 - Copy.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_91 - Copy (3).jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_30.jpg
# /kaggle/input/insectv2-dataset/pest/train/mites/jpg_13 - Copy.jpg
pg
# /kaggle/input/insectv2-dataset/pest/train/bollworm/jpg_84.jpg
# /kaggle/input/insectv2-dataset/pest/train/bollworm/jpg_84 - Copy.jpg

# %% [markdown]
# ## TITLE: Deep Learning for Precision Agriculture: The BAU-Insectv2 Dataset

# %% [markdown]
# **1. Overview**
# **The BAU-Insectv2 Agricultural Plant Insect Dataset is a publicly available collection of high-resolution images designed for deep learning applications in agricultural pest detection. It was developed through a collaboration between Daffodil International University, Bangladesh Agricultural University, and Dongseo University, with the aim of improving precision agriculture by leveraging artificial intelligence for insect identification.**
#
# **2. Purpose and Importance**
#
# **Pests and insects significantly impact crop yields and food security. Traditional pest control methods often rely on manual inspection, which is time-consuming and prone to errors. The BAU-Insectv2 dataset is specifically designed to aid AI-powered solutions for real-time pest detection, monitoring, and classification. By training convolutional neural networks (CNNs) and other machine learning models with this dataset, researchers can develop automated systems for precision agriculture, reducing reliance on pesticides and improving early pest detection.**
#
# **3. Key Features of the Dataset**
#
# **Diverse Image Collection: The dataset consists of over 2,000 high-resolution images spanning multiple classes of agricultural insects.
# High-Quality Images: Each image captures detailed views of plant-insect interactions, ensuring accurate feature extraction for deep learning models.
# Class Labeling: The dataset is labeled into nine distinct insect categories, allowing for multi-class classification problems.
# Designed for Deep Learning: Optimized for training CNNs and other AI-based computer vision models to detect and classify insects.
# Focus on South Asian Agriculture: The dataset is particularly relevant for pest management in Bangladesh, India, and neighboring agricultural regions.
# Availability: The dataset is publicly available under the Creative Commons Attribution 4.0 International License, making it freely accessible for academic and industrial research.**
#
# **4. Dataset Composition and Structure**
#
# **The BAU-Insectv2 dataset contains images of insects commonly found in agricultural fields, classified based on species and their impact on crops. The dataset structure follows a folder-based arrangement, where each category represents a specific insect type.**
#
# Classes in the Dataset (Example)
#
# Aphids – Sap-sucking pests that weaken plants.
#
# Beetles – A diverse group of insects, some of which are harmful to crops.
#
# Caterpillars – Larvae of moths and butterflies that feed on leaves.
#
# Grasshoppers – Known for causing defoliation in crops.
#
# Leafhoppers – Insects that spread plant diseases through feeding.
#
# Whiteflies – Tiny insects that damage plants by sucking sap.
#
# Thrips – Small pests that cause significant damage to flowers and vegetables.
#
# Weevils – Insects that infest stored grains and crops.
#
# Moths – Some species lay eggs on crops, leading to caterpillar infestations.
#
# Each image is annotated with metadata that includes insect species, location, and plant type.
#
# **5. Applications of BAU-Insectv2 Dataset**
#
# The dataset provides a strong foundation for multiple research areas:
#
# Automated Pest Detection – AI models can identify and categorize pests in real-time using drones or smart devices.
#
# Precision Agriculture – Early detection of pests helps in targeted pesticide application, reducing chemical usage.
#
# Computer Vision Research – Researchers can use the dataset to train CNNs, YOLO, or Vision Transformers for object detection and classification.
#
# AgriTech Development – AI-based mobile applications and IoT devices for real-time pest monitoring can be developed.
#
# Disease Spread Analysis – Insects that transmit plant diseases can be tracked using AI-driven forecasting models.
#
# **6. Research Opportunities**
# The dataset opens new avenues for agricultural and AI research, including:
#
# Transfer Learning – Fine-tuning pre-trained models (ResNet, EfficientNet, etc.) on the dataset.
#
# Few-Shot Learning – Developing models that require fewer training samples.
#
# Generative AI in Agriculture – Using GANs to create synthetic insect images for data augmentation.
#
# Explainable AI (XAI) – Understanding how AI models classify insects through saliency maps and heatmaps.

# %% [markdown]
# ## Import libraries

# %%
import os
from tqdm import tqdm
import numpy as np

# %%
# Machine Learning utilities
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc

# %%
# Deep Learning libraries
import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical
from keras.applications.vgg16 import VGG16
from keras.layers import Dense, Flatten
from keras.models import Model

# %%
import cv2  
import matplotlib.pyplot as plt

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import dataset

# %%
directory = '/kaggle/input/insectv2-dataset/pest/train'

img = [name for name in os.listdir(directory) if os.path.isdir(os.path.join(directory, name))]

# %%
img
# Out:
# ['beetle',
#  'mites',
#  'grasshopper',
#  'sawfly',
#  'stem_borer',
#  'mosquito',
#  'armyworm',
#  'aphids',
#  'bollworm']

# %%
import os
print(os.listdir("/kaggle/input/"))
# Out:
# ['insectv2-dataset']

# %%
print(os.listdir("/kaggle/input/insectv2-dataset/pest/"))
# Out:
# ['test', 'train']

# %%
import os

# Detect dataset structure
dataset_root = "/kaggle/input/insectv2-dataset"
subdirs = os.listdir(dataset_root)
print("Dataset structure:", subdirs)

# Determine if 'pest/' is required
if "pest" in subdirs:
    dataset_root = os.path.join(dataset_root, "pest")

# Now proceed with loading the images
data_dirs = ["train", "test"]
labels = os.listdir(os.path.join(dataset_root, "train"))  # Auto-detect labels

image_data, label_data = [], []
image_size = 150

for data_dir in data_dirs:
    print(f"📂 Processing '{data_dir}' directory...")
    
    for label_idx, label in enumerate(labels):
        data_path = os.path.join(dataset_root, data_dir, label)

        if not os.path.exists(data_path):
            print(f"⚠️ Warning: Missing directory - {data_path}")
            continue

        for img_file in os.listdir(data_path):
            img_path = os.path.join(data_path, img_file)
            image = cv2.imread(img_path)

            if image is None:
                print(f"❌ Skipping corrupted file: {img_path}")
                continue

            image = cv2.resize(image, (image_size, image_size))
            image_data.append(image)
            label_data.append(label_idx)

print(f"\n✅ Data processing complete! Loaded {len(image_data)} images.")
# Out:
# Dataset structure: ['pest']
# 📂 Processing 'train' directory...
# 📂 Processing 'test' directory...
#
# ✅ Data processing complete! Loaded 2616 images.

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

image_data, label_data = shuffle(image_data, label_data, random_state=42)
image_data = np.array(image_data, dtype=np.float32) / 255.0
label_data = np.array(label_data, dtype=np.int32)  
X_train, X_test, Y_train, Y_test = train_test_split(image_data, label_data, test_size=0.2, random_state=42)

print(f"✅ Data ready for training! Training samples: {len(X_train)}, Test samples: {len(X_test)}")
# Out:
# ✅ Data ready for training! Training samples: 2092, Test samples: 524

# %%
from keras.utils import to_categorical

Y_train = np.array(Y_train, dtype=np.int32)
Y_test = np.array(Y_test, dtype=np.int32)

Y_train = to_categorical(Y_train, num_classes=len(labels))
Y_test = to_categorical(Y_test, num_classes=len(labels))

print(f"✅ Labels converted to one-hot encoding. Shape: {Y_train.shape}")
# Out:
# ✅ Labels converted to one-hot encoding. Shape: (2092, 9)

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import Dense, Flatten, Dropout
from keras.models import Model



vgg = VGG16(input_shape=(150,150,3), weights='imagenet', include_top=False)
for layer in vgg.layers:
    layer.trainable = False  
x = Flatten()(vgg.output)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)  # Prevents overfitting
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
prediction = Dense(len(labels), activation='softmax')(x)  # Dynamic class count
modelvgg = Model(inputs=vgg.input, outputs=prediction)
modelvgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 150, 150, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 150, 150, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 75, 75, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 75, 75, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 75, 75, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 37, 37, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 37, 37, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 37, 37, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 37, 37, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 18, 18, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 18, 18, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 18, 18, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 18, 18, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 9, 9, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 9, 9, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 9, 9, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 9, 9, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       4,194,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 9)                   │           2,313 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,043,145 (72.64 MB)
#  Trainable params: 4,328,457 (16.51 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.losses import CategoricalCrossentropy
from keras.metrics import AUC

modelvgg.compile(
    optimizer=Adam(learning_rate=0.0001),  
    loss=CategoricalCrossentropy(),
    metrics=['accuracy', AUC(name='auc')]
)

callback = EarlyStopping(
    monitor='val_loss', patience=8, restore_best_weights=True, verbose=1
)

print("✅ Model compiled successfully!")
# Out:
# ✅ Model compiled successfully!

# %%
history = modelvgg.fit(
    X_train, Y_train,
    epochs=50,              
    batch_size=32,         
    validation_data=(X_test, Y_test),
    callbacks=[callback],  
    verbose=1
)
# Out:
# Epoch 1/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 27s 221ms/step - accuracy: 0.1987 - auc: 0.5913 - loss: 2.3329 - val_accuracy: 0.6985 - val_auc: 0.9395 - val_loss: 1.4557
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.4696 - auc: 0.8488 - loss: 1.5358 - val_accuracy: 0.7977 - val_auc: 0.9751 - val_loss: 0.9252
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.6516 - auc: 0.9315 - loss: 1.0788 - val_accuracy: 0.8779 - val_auc: 0.9900 - val_loss: 0.6083
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.7725 - auc: 0.9695 - loss: 0.7732 - val_accuracy: 0.9179 - val_auc: 0.9955 - val_loss: 0.3882
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.8439 - auc: 0.9848 - loss: 0.5669 - val_accuracy: 0.9656 - val_auc: 0.9983 - val_loss: 0.2501
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.9073 - auc: 0.9940 - loss: 0.3940 - val_accuracy: 0.9714 - val_auc: 0.9988 - val_loss: 0.1810
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.9271 - auc: 0.9968 - loss: 0.2907 - val_accuracy: 0.9828 - val_auc: 0.9985 - val_loss: 0.1109
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.9504 - auc: 0.9982 - loss: 0.2187 - val_accuracy: 0.9866 - val_auc: 0.9987 - val_loss: 0.0838
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9662 - auc: 0.9991 - loss: 0.1710 - val_accuracy: 0.9943 - val_auc: 0.9987 - val_loss: 0.0635
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.9767 - auc: 0.9997 - loss: 0.1277 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0441
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9798 - auc: 0.9997 - loss: 0.1067 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0348
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9892 - auc: 0.9997 - loss: 0.0799 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0307
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9863 - auc: 0.9998 - loss: 0.0764 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0307
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.9936 - auc: 1.0000 - loss: 0.0574 - val_accuracy: 0.9943 - val_auc: 0.9990 - val_loss: 0.0266
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 105ms/step - accuracy: 0.9939 - auc: 1.0000 - loss: 0.0451 - val_accuracy: 0.9943 - val_auc: 0.9990 - val_loss: 0.0243
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 102ms/step - accuracy: 0.9932 - auc: 1.0000 - loss: 0.0408 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0275
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9965 - auc: 0.9999 - loss: 0.0357 - val_accuracy: 0.9943 - val_auc: 0.9990 - val_loss: 0.0264
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9966 - auc: 1.0000 - loss: 0.0267 - val_accuracy: 0.9943 - val_auc: 0.9990 - val_loss: 0.0235
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9934 - auc: 0.9999 - loss: 0.0436 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0243
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9959 - auc: 1.0000 - loss: 0.0297 - val_accuracy: 0.9962 - val_auc: 0.9989 - val_loss: 0.0232
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9972 - auc: 1.0000 - loss: 0.0225 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0230
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9980 - auc: 1.0000 - loss: 0.0184 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0249
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9968 - auc: 1.0000 - loss: 0.0214 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0259
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - accuracy: 0.9989 - auc: 1.0000 - loss: 0.0154 - val_accuracy: 0.9962 - val_auc: 0.9989 - val_loss: 0.0254
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0219 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0268
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9995 - auc: 1.0000 - loss: 0.0122 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0281
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9986 - auc: 1.0000 - loss: 0.0155 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0233
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9977 - auc: 1.0000 - loss: 0.0131 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0240
# Epoch 29/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 7s 101ms/step - accuracy: 0.9985 - auc: 1.0000 - loss: 0.0145 - val_accuracy: 0.9943 - val_auc: 0.9989 - val_loss: 0.0232
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']


plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss', color='blue')
plt.plot(val_loss, label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss Curve')

plt.subplot(1, 2, 2)
plt.plot(accuracy, label='Train Accuracy', color='blue')
plt.plot(val_accuracy, label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy Curve')

plt.show()

# %%
# Evaluate on Train Data
train_results = modelvgg.evaluate(X_train, Y_train, verbose=1)
train_loss, train_acc, train_auc = train_results  # Unpacking 3 values

# Evaluate on Test Data
test_results = modelvgg.evaluate(X_test, Y_test, verbose=1)
test_loss, test_acc, test_auc = test_results  # Unpacking 3 values

# Print Results
print(f"✅ Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Train AUC: {train_auc:.4f}")
print(f"✅ Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}, Test AUC: {test_auc:.4f}")
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 0.0019
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9915 - auc: 0.9996 - loss: 0.0204
# ✅ Train Loss: 0.0025, Train Accuracy: 0.9990, Train AUC: 1.0000
# ✅ Test Loss: 0.0230, Test Accuracy: 0.9943, Test AUC: 0.9989

# %%
train_results = modelvgg.evaluate(X_train, Y_train, verbose=1)
print(f"Train Results: {train_results}")  

test_results = modelvgg.evaluate(X_test, Y_test, verbose=1)
print(f"Test Results: {test_results}")
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 0.0019
# Train Results: [0.0024898506235331297, 0.9990440011024475, 0.9999998807907104]
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9915 - auc: 0.9996 - loss: 0.0204
# Test Results: [0.023009100928902626, 0.9942747950553894, 0.9989119172096252]

# %%
predictions = modelvgg.predict(X_test, verbose=1)  
y_pred = np.argmax(predictions, axis=1)  
y_test = np.argmax(Y_test, axis=1)  

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

display_cm = ConfusionMatrixDisplay(cm, display_labels=labels)
display_cm.plot(cmap="Blues", xticks_rotation=45)  
plt.title("Confusion Matrix")
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# Confusion Matrix:
#  [[81  0  0  0  0  0  0  0  0]
#  [ 0 59  0  0  0  0  0  0  0]
#  [ 0  0 62  0  0  0  0  0  0]
#  [ 0  0  0 49  0  0  0  1  0]
#  [ 0  0  0  1 43  0  0  0  0]
#  [ 0  0  0  0  0 61  0  0  0]
#  [ 0  0  0  0  0  0 53  0  1]
#  [ 0  0  0  0  0  0  0 55  0]
#  [ 0  0  0  0  0  0  0  0 58]]

# %%
display_cm = ConfusionMatrixDisplay(cm, display_labels=labels)
display_cm.plot(cmap='OrRd', xticks_rotation=90)  # Proper method call

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title('Confusion Matrix', fontsize=24)
plt.show()

print("Classification Report:\n", classification_report(y_test, y_pred, target_names=labels))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       beetle       1.00      1.00      1.00        81
#        mites       1.00      1.00      1.00        59
#  grasshopper       1.00      1.00      1.00        62
#       sawfly       0.98      0.98      0.98        50
#   stem_borer       1.00      0.98      0.99        44
#     mosquito       1.00      1.00      1.00        61
#     armyworm       1.00      0.98      0.99        54
#       aphids       0.98      1.00      0.99        55
#     bollworm       0.98      1.00      0.99        58
#
#     accuracy                           0.99       524
#    macro avg       0.99      0.99      0.99       524
# weighted avg       0.99      0.99      0.99       524

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
import seaborn as sns
from matplotlib.cm import get_cmap

n_classes = Y_test.shape[1]

fpr = {} 
tpr = {}  
roc_auc = {} 

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(Y_test[:, i], predictions[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


sns.set_style("whitegrid")

plt.figure(figsize=(10, 8))
cmap = get_cmap("rainbow", n_classes)  

for i in range(n_classes):
    plt.plot(
        fpr[i], tpr[i], color=cmap(i / n_classes), lw=2,
        label=f'Class {labels[i]} (AUC = {roc_auc[i]:.2f})'
    )

plt.plot([0, 1], [0, 1], 'k--', lw=2, label="Random Guessing")


plt.xlim([-0.02, 1.0])
plt.ylim([0.0, 1.02])
plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold')
plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold')
plt.title('Multi-Class ROC Curve', fontsize=18, fontweight='bold', color="darkblue")

# Add legend and grid
plt.legend(loc="lower right", fontsize=12, frameon=True, shadow=True)
plt.grid(alpha=0.3)

# Save and show plot
plt.savefig("Enhanced_ROC_Curve.png", dpi=600, bbox_inches='tight', transparent=True)
plt.show()

# %% [markdown]
# ## Thank you!!! pls upvote...!!!!
